# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
# %matplotlib inline

pop1 = np.random.binomial(10, 0.2, 10000)
pop2 = np.random.binomial(10,0.5, 10000) 

plt.hist(pop1, alpha=0.5, label='Population 1') 
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.legend(loc='upper right') 
plt.title('population distribution')
plt.show()


sample1 = np.random.choice(pop1, 100, replace=True)
sample2 = np.random.choice(pop2, 100, replace=True)

plt.hist(sample1, alpha=0.5, label='sample 1', normed= True) 
plt.hist(sample2, alpha=0.5, label='sample 2', normed= True) 
plt.legend(loc='upper right') 
plt.title('sample distribution')
plt.show()
print('sample1 mean :' , sample1.mean())
print('sample2 mean :' , sample2.mean())
print('sample1 std :' , sample1.std())
print('sample2 std :' , sample2.std())
# Out:
# sample1 mean : 1.93
# sample2 mean : 4.88
# sample1 std : 1.22682517092
# sample2 std : 1.48512625726

# %%
#1. a. 
pop1 = np.random.binomial(10, 0.2, 10000)
pop2 = np.random.binomial(10,0.5, 10000) 

sample1 = np.random.choice(pop1, 1000, replace=True)
sample2 = np.random.choice(pop2, 1000, replace=True)

print('sample1 mean :' , sample1.mean())
print('sample2 mean :' , sample2.mean())
print('sample1 std :' , sample1.std())
print('sample2 std :' , sample2.std())

plt.hist(sample1, alpha=0.5, label='sample 1', normed= True) 
plt.hist(sample2, alpha=0.5, label='sample 2', normed= True) 
plt.legend(loc='upper right') 
plt.title('sample distribution')
plt.show()
# Out:
# sample1 mean : 2.042
# sample2 mean : 4.892
# sample1 std : 1.2713127074
# sample2 std : 1.55702793809

# %%
#1. b.
pop1 = np.random.binomial(10, 0.2, 10000)
pop2 = np.random.binomial(10,0.5, 10000) 

sample1 = np.random.choice(pop1, 20, replace=True)
sample2 = np.random.choice(pop2, 20, replace=True)

print('sample1 mean :' , sample1.mean())
print('sample2 mean :' , sample2.mean())
print('sample1 std :' , sample1.std())
print('sample2 std :' , sample2.std())

plt.hist(sample1, alpha=0.5, label='sample 1', normed= True) 
plt.hist(sample2, alpha=0.5, label='sample 2', normed= True) 
plt.legend(loc='upper right') 
plt.title('sample distribution')
plt.show()
# Out:
# sample1 mean : 1.7
# sample2 mean : 4.9
# sample1 std : 0.781024967591
# sample2 std : 1.33790881603

# %%
#2. a.
pop1 = np.random.binomial(10, 0.3, 10000)
pop2 = np.random.binomial(10,0.5, 10000) 

sample1 = np.random.choice(pop1, 1000, replace=True)
sample2 = np.random.choice(pop2, 1000, replace=True)

print('population 1 mean: ',pop1.mean())
print('population 1 std: ',pop1.std())
print('sample1 mean :' , sample1.mean())
print('sample1 std :' , sample1.std())

print('population 2 mean: ',pop2.mean())
print('population 2 std: ',pop2.std())
print('sample2 mean :' , sample2.mean())
print('sample2 std :' , sample2.std())

plt.hist(sample1, alpha=0.5, label='sample 1', normed= True) 
plt.hist(sample2, alpha=0.5, label='sample 2', normed= True) 
plt.legend(loc='upper right') 
plt.title('sample distribution')
plt.show()

diff=sample2.mean( ) -sample1.mean()
print('difference between the two sample means : ', diff)

size = np.array([len(sample1), len(sample2)])
sd = np.array([sample1.std(), sample2.std()])


diff_se = (sum(sd ** 2 / size)) ** 0.5  


print('T value calculated : ', diff/diff_se)

from scipy.stats import ttest_ind
print('values from ttest : ', ttest_ind(sample2, sample1, equal_var=False))
# Out:
# population 1 mean:  2.9873
# population 1 std:  1.44663012204
# sample1 mean : 2.963
# sample1 std : 1.46820672931
# population 2 mean:  4.9746
# population 2 std:  1.588066384
# sample2 mean : 5.002
# sample2 std : 1.63462411581
# difference between the two sample means :  2.039
# T value calculated :  29.3460985735
# values from ttest :  Ttest_indResult(statistic=29.331421854128632, pvalue=2.7138947117034472e-157)

# %%
#2. b.
pop1 = np.random.binomial(10, 0.4, 10000)
pop2 = np.random.binomial(10,0.5, 10000) 

sample1 = np.random.choice(pop1, 1000, replace=True)
sample2 = np.random.choice(pop2, 1000, replace=True)

print('population 1 mean: ',pop1.mean())
print('population 1 std: ',pop1.std())
print('sample1 mean :' , sample1.mean())
print('sample1 std :' , sample1.std())

print('population 2 mean: ',pop2.mean())
print('population 2 std: ',pop2.std())
print('sample2 mean :' , sample2.mean())
print('sample2 std :' , sample2.std())

plt.hist(sample1, alpha=0.5, label='sample 1', normed= True) 
plt.hist(sample2, alpha=0.5, label='sample 2', normed= True) 
plt.legend(loc='upper right') 
plt.title('sample distribution')

diff=sample2.mean( ) -sample1.mean()
print('difference between the two sample means : ', diff)

size = np.array([len(sample1), len(sample2)])
sd = np.array([sample1.std(), sample2.std()])


diff_se = (sum(sd ** 2 / size)) ** 0.5  

#The difference between the means divided by the standard error: T-value.  
print('T value calculated : ', diff/diff_se)

from scipy.stats import ttest_ind
print('values from ttest : ', ttest_ind(sample2, sample1, equal_var=False))
# Out:
# population 1 mean:  3.9802
# population 1 std:  1.54337550842
# sample1 mean : 4.073
# sample1 std : 1.48042932962
# population 2 mean:  5.0003
# population 2 std:  1.56968146769
# sample2 mean : 4.983
# sample2 std : 1.59897185716
# difference between the two sample means :  0.91
# T value calculated :  13.2059171198
# values from ttest :  Ttest_indResult(statistic=13.199312509644505, pvalue=3.4155770084929894e-38)

# %% [markdown]
# #3.
# As per the Central Limit Theorem , no matter what distribution is choosen, normal distributions can still be used to calculate statistics as long as the sample size is large enough.
